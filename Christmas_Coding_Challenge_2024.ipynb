# %% [markdown]
# <a href="https://colab.research.google.com/github/lerissamistry/Christmas-Coding-Challenge-2024/blob/main/Christmas_Coding_Challenge_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 1

# %% [markdown]
# Today I have created an artificial data set using python.

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %%
# Define date range
start_date = datetime(2024, 12, 1)
end_date = datetime(2024, 12, 31)
date_range = pd.date_range(start=start_date, end=end_date, freq='D')

# Generate dummy data
data = {
    "Date": date_range,
    "Heart Rate (bpm)": np.random.randint(60, 120, size=len(date_range)),
    "Steps": np.random.randint(2000, 15000, size=len(date_range)),
    "Calories Burned (kcal)": np.random.randint(1500, 3500, size=len(date_range)),
    "Active Hours (hrs)": np.random.uniform(1, 8, size=len(date_range)).round(2),
    "Stand Hours (hrs)": np.random.randint(8, 16, size=len(date_range)),
    "Sleep Hours (hrs)": np.random.uniform(5, 9, size=len(date_range)).round(2),
    "Activity Ring Completion (%)": np.random.randint(50, 100, size=len(date_range)),
}

# Create DataFrame
df = pd.DataFrame(data)

# %%
df
# Out:
#          Date  Heart Rate (bpm)  Steps  Calories Burned (kcal)  \
# 0  2024-12-01               112   9718                    1973
# 1  2024-12-02                86   6569                    2945
# 2  2024-12-03                64   4089                    3034
# 3  2024-12-04                75   4607                    3134
# 4  2024-12-05               110  14858                    2429
# 5  2024-12-06                95   4348                    2627
# 6  2024-12-07               117   8909                    2157
# 7  2024-12-08                79   5155                    1790
# 8  2024-12-09               104   6853                    2800
# 9  2024-12-10               115  14239                    2783
# 10 2024-12-11                97  14153                    2044
# 11 2024-12-12               109   6067                    2352
# 12 2024-12-13                68   3036                    2497
# 13 2024-12-14                87   8474                    2171
# 14 2024-12-15                74   2847                    2902
# 15 2024-12-16                85  11716                    2668
# 16 2024-12-17                78  14276                    1553
# 17 2024-12-18                97  12667                    3303
# 18 2024-12-19                66   2083                    3326
# 19 2024-12-20                73   2896                    3391
# 20 2024-12-21               114   8949                    3186
# 21 2024-12-22                62  14084                    1884
# 22 2024-12-23                93   8410                    2403
# 23 2024-12-24               110   9025                    3320
# 24 2024-12-25                61   5040                    3044
# 25 2024-12-26               102   6855                    2393
# 26 2024-12-27               118   4325                    1945
# 27 2024-12-28                81   7046                    1531
# 28 2024-12-29                77   9841                    3384
# 29 2024-12-30               107   7769                    1979
# 30 2024-12-31                78  12660                    3027
#
#     Active Hours (hrs)  Stand Hours (hrs)  Sleep Hours (hrs)  \
# 0                 6.80                 10               8.26
# 1                 5.08                 10               5.56
# 2                 1.51                  8               6.36
# 3                 6.63                 13               6.67
# 4                 5.38                 15               6.38
# 5                 1.51                 13               8.95
# 6                 3.96                 15               5.32
# 7                 4.82                 10               7.67
# 8                 6.68                  8               7.80
# 9                 2.14                 13               5.72
# 10                2.28                  8               5.75
# 11                5.75                  8               7.54
# 12                7.68                 14               5.97
# 13                6.46                  8               5.44
# 14                2.66                 10               5.56
# 15                5.05                 14               7.80
# 16                7.45                 14               8.51
# 17                5.63                  8               9.00
# 18                4.01                 12               5.50
# 19                7.56                  8               8.37
# 20                3.75                 13               7.49
# 21                1.80                 12               8.26
# 22                5.48                 15               8.67
# 23                4.60                 15               8.14
# 24                1.48                 15               5.24
# 25                3.52                 11               8.00
# 26                6.99                 13               7.98
# 27                7.43                  8               5.43
# 28                2.93                 11               7.11
# 29                4.80                 14               5.85
# 30                7.18                  9               6.62
#
#     Activity Ring Completion (%)
# 0                             76
# 1                             78
# 2                             69
# 3                             83
# 4                             75
# 5                             78
# 6                             82
# 7                             53
# 8                             73
# 9                             54
# 10                            65
# 11                            93
# 12                            50
# 13                            97
# 14                            88
# 15                            61
# 16                            65
# 17                            79
# 18                            55
# 19                            69
# 20                            95
# 21                            69
# 22                            60
# 23                            93
# 24                            99
# 25                            59
# 26                            60
# 27                            99
# 28                            72
# 29                            82
# 30                            67
