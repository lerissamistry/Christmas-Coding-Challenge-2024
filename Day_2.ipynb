# %% [markdown]
# <a href="https://colab.research.google.com/github/lerissamistry/Christmas-Coding-Challenge-2024/blob/main/Day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %%
# Define date range
start_date = datetime(2024, 12, 1)
end_date = datetime(2024, 12, 31)
date_range = pd.date_range(start=start_date, end=end_date, freq='D')

# Generate dummy data
data = {
    "Date": date_range,
    "Heart Rate (bpm)": np.random.randint(60, 120, size=len(date_range)),
    "Steps": np.random.randint(2000, 15000, size=len(date_range)),
    "Calories Burned (kcal)": np.random.randint(1500, 3500, size=len(date_range)),
    "Active Hours (hrs)": np.random.uniform(1, 8, size=len(date_range)).round(2),
    "Stand Hours (hrs)": np.random.randint(8, 16, size=len(date_range)),
    "Sleep Hours (hrs)": np.random.uniform(5, 9, size=len(date_range)).round(2),
    "Activity Ring Completion (%)": np.random.randint(50, 100, size=len(date_range)),
}

# Create DataFrame
df = pd.DataFrame(data)

# %%
df
# Out:
#          Date  Heart Rate (bpm)  Steps  Calories Burned (kcal)  \
# 0  2024-12-01                70   4165                    1791
# 1  2024-12-02                73   3100                    2817
# 2  2024-12-03               104   7967                    1675
# 3  2024-12-04               109   2338                    2692
# 4  2024-12-05               116  10123                    2488
# 5  2024-12-06                73  12465                    2218
# 6  2024-12-07                79  12094                    3060
# 7  2024-12-08                64   6054                    2204
# 8  2024-12-09               118   3205                    1703
# 9  2024-12-10                71   6816                    2363
# 10 2024-12-11                92   8208                    2507
# 11 2024-12-12                80   7253                    3177
# 12 2024-12-13                80   8108                    2868
# 13 2024-12-14               113   8701                    3221
# 14 2024-12-15                77   5926                    3125
# 15 2024-12-16                74   6726                    2028
# 16 2024-12-17                87   3124                    3118
# 17 2024-12-18               104   7357                    1880
# 18 2024-12-19               112  10683                    3211
# 19 2024-12-20                90   2955                    2799
# 20 2024-12-21                87   6264                    1806
# 21 2024-12-22                92  12191                    2776
# 22 2024-12-23                85   9151                    1920
# 23 2024-12-24                86  13588                    2370
# 24 2024-12-25                79   2680                    2937
# 25 2024-12-26                76   4780                    3468
# 26 2024-12-27                85  13143                    2995
# 27 2024-12-28                96   6591                    2870
# 28 2024-12-29                72   9801                    2687
# 29 2024-12-30                92   2372                    2813
# 30 2024-12-31               113   3552                    2507
#
#     Active Hours (hrs)  Stand Hours (hrs)  Sleep Hours (hrs)  \
# 0                 1.59                 13               6.17
# 1                 1.96                  8               5.71
# 2                 2.40                 15               6.41
# 3                 7.98                 14               5.02
# 4                 1.97                 12               7.57
# 5                 6.92                 10               8.39
# 6                 7.15                 15               7.55
# 7                 4.21                 10               8.64
# 8                 2.66                 10               6.94
# 9                 2.91                 10               5.26
# 10                6.22                  8               6.05
# 11                3.61                 10               7.29
# 12                1.17                 10               5.28
# 13                2.20                 14               6.33
# 14                1.37                  9               8.51
# 15                7.16                  8               7.91
# 16                6.24                 13               6.51
# 17                1.58                 14               8.78
# 18                4.56                 10               7.62
# 19                2.85                 12               5.71
# 20                3.10                 11               8.42
# 21                5.20                 14               8.17
# 22                5.07                  9               6.66
# 23                1.06                  8               7.25
# 24                5.42                  9               7.51
# 25                5.09                 15               5.90
# 26                6.78                 12               8.15
# 27                6.58                 13               7.56
# 28                6.52                 15               6.67
# 29                7.23                 13               5.04
# 30                3.65                 10               8.01
#
#     Activity Ring Completion (%)
# 0                             92
# 1                             94
# 2                             52
# 3                             62
# 4                             83
# 5                             97
# 6                             66
# 7                             79
# 8                             55
# 9                             66
# 10                            69
# 11                            61
# 12                            72
# 13                            52
# 14                            53
# 15                            88
# 16                            60
# 17                            59
# 18                            85
# 19                            97
# 20                            58
# 21                            62
# 22                            83
# 23                            68
# 24                            96
# 25                            66
# 26                            70
# 27                            66
# 28                            67
# 29                            89
# 30                            96

# %% [markdown]
# Day 2
#
#
#
# *   Experimenting Using Matplotlib
# *   Synthetic data appears to be very sporadic

# %%
import matplotlib.pyplot as plt

# %%
df.plot(x='Date', y='Calories Burned (kcal)')
plt.title('Calories Burned Over Time')
plt.xlabel('Date')
plt.ylabel('Calories Burned (kcal)')
plt.show()

# %%
df.plot(x='Date', y='Activity Ring Completion (%)')
plt.title('Activity Ring Completion Over Time')
plt.xlabel('Date')
plt.ylabel('Activity Ring Completion (%)')
plt.show()

# %%
df.plot(x='Date', y='Stand Hours (hrs)')
plt.title('Stand Hours (hrs) Over Time')
plt.xlabel('Date')
plt.ylabel('Stand Hours (hrs)')
plt.show()
