# %% [markdown]
# <a href="https://colab.research.google.com/github/lerissamistry/Christmas-Coding-Challenge-2024/blob/main/Day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %%
# Define date range
start_date = datetime(2024, 12, 1)
end_date = datetime(2024, 12, 31)
date_range = pd.date_range(start=start_date, end=end_date, freq='D')

# Generate dummy data
data = {
    "Date": date_range,
    "Heart Rate (bpm)": np.random.randint(60, 120, size=len(date_range)),
    "Steps": np.random.randint(2000, 15000, size=len(date_range)),
    "Calories Burned (kcal)": np.random.randint(1500, 3500, size=len(date_range)),
    "Active Hours (hrs)": np.random.uniform(1, 8, size=len(date_range)).round(2),
    "Stand Hours (hrs)": np.random.randint(8, 16, size=len(date_range)),
    "Sleep Hours (hrs)": np.random.uniform(5, 9, size=len(date_range)).round(2),
    "Activity Ring Completion (%)": np.random.randint(50, 100, size=len(date_range)),
}

# Create DataFrame
df = pd.DataFrame(data)

# %%
# Visualize Trends: Create a time-series line plot to show how Steps and Calories Burned vary over time.
df.plot(x='Date', y=['Steps', 'Calories Burned (kcal)'], kind='line')
# Out:
# <Axes: xlabel='Date'>

# %%
# Analyze Top Performances:
# Identify the day with the highest activity ring completion.
df['Activity Ring Completion (%)'].idxmax()
# Out:
# 8

# %%
# Analyse Top Performances:
# Identify the top 5 rows with the highest activity ring completion.
df.nlargest(5, 'Activity Ring Completion (%)')
# Out:
#          Date  Heart Rate (bpm)  Steps  Calories Burned (kcal)  \
# 8  2024-12-09                93   7671                    2032
# 11 2024-12-12               101  11824                    2947
# 23 2024-12-24                95  14796                    2089
# 18 2024-12-19                63  13722                    3373
# 20 2024-12-21                69   3083                    3065
#
#     Active Hours (hrs)  Stand Hours (hrs)  Sleep Hours (hrs)  \
# 8                 3.48                  9               8.02
# 11                6.27                 12               6.83
# 23                7.93                 14               8.73
# 18                7.92                  8               8.55
# 20                1.34                 12               8.33
#
#     Activity Ring Completion (%)
# 8                             99
# 11                            97
# 23                            94
# 18                            90
# 20                            89

# %%
# Analyse Top Performances:
# Identify the top 5 rows with the highest activity ring completion.
df.nlargest(5, 'Steps')
# Out:
#          Date  Heart Rate (bpm)  Steps  Calories Burned (kcal)  \
# 14 2024-12-15               108  14806                    2131
# 23 2024-12-24                95  14796                    2089
# 30 2024-12-31                70  14307                    3007
# 19 2024-12-20                87  14191                    3422
# 24 2024-12-25                86  14063                    2893
#
#     Active Hours (hrs)  Stand Hours (hrs)  Sleep Hours (hrs)  \
# 14                4.38                 13               5.15
# 23                7.93                 14               8.73
# 30                2.80                 12               6.73
# 19                6.29                  8               8.36
# 24                4.54                 14               8.06
#
#     Activity Ring Completion (%)
# 14                            68
# 23                            94
# 30                            64
# 19                            68
# 24                            58
